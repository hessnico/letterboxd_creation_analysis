# %%
# Out:
#       imdb_rating  imdb_total_votes date_watched  \
# 0             6.4            500429   2021-05-01
# 1             6.2             51753   2021-05-01
# 2             7.7            783473   2021-05-01
# 3             7.5             61193   2021-05-01
# 4             6.6             21719   2021-05-01
# ...           ...               ...          ...
# 1168          7.3            165842   2022-11-06
# 1169          6.8              1506   2022-11-07
# 1170          6.0             30551   2022-11-07
# 1171          5.4              1949   2022-11-07
# 1172          6.6             64240   2022-11-07
#
#                                           title  release_year  \
# 0                          The Hangover Part II          2011
# 1                          Diary of a Wimpy Kid          2010
# 2                                  The Hangover          2009
# 3                                    The Player          1992
# ...
